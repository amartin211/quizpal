# %%
from image_preprocessing import preprocessing_raw_image_without_crop_screen
import os

raw_folder_path = "/home/aime/python-environments/exam_script_deploy/raw_images (copy)"
cropped_rotated_folder_path = "/home/aime/python-environments/exam_script_deploy/cropped_exam_photos"

for file in os.listdir(raw_folder_path):
    if file.endswith(".jpg"):
        raw_image_path = os.path.join(raw_folder_path, file)
        cropped_image_path = os.path.join(cropped_rotated_folder_path, file)
        preprocessing_raw_image_without_crop_screen(raw_image_path, cropped_image_path)
# Out:
# /home/aime/python-environments/exam_script_deploy/raw_images (copy)/0731a59a32d9810a_jpg.rf.0dacf4191d1c5de05e75fdeceb31a453.jpg
# image 1/1 /home/aime/python-environments/exam_script_deploy/raw_images (copy)/0731a59a32d9810a_jpg.rf.0dacf4191d1c5de05e75fdeceb31a453.jpg: 640x640 4 tvs, 122.7ms
# Speed: 1.6ms preprocess, 122.7ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# /home/aime/python-environments/exam_script_deploy/raw_images (copy)/dad7d7b2b3a9a27c_jpg.rf.5478309e805d4d095abe4c1e13f8c635.jpg
# image 1/1 /home/aime/python-environments/exam_script_deploy/raw_images (copy)/dad7d7b2b3a9a27c_jpg.rf.5478309e805d4d095abe4c1e13f8c635.jpg: 640x640 1 tv, 1 laptop, 92.1ms
# Speed: 0.7ms preprocess, 92.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# /home/aime/python-environments/exam_script_deploy/raw_images (copy)/image_20240405_102949.jpg
# ...

# %%
len(os.listdir(raw_folder_path))
